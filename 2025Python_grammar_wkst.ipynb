# %% [markdown]
# # Python 基本语法
# ## 负一、虚拟环境配置（非必须）
# Environment_25DL.pdf
#
# 来自Deep Learning wksp
# ## 零、建议大家都有美好的VSCode
# 详情请见文档：Jupyter Notebook Configuration.docx
#
# 包含Anaconda、VSCode、Python and Jupyter Notebook in VSCode
#
# ## 零点一、Jupyter 环境配置（已有VScode版）
#
# 一款拯救主讲人的集Markdown和Python于一身的好东西。
#
#
# 在vscode的左侧，找到“插件”
#
# ![插件.png](attachment:1752756268746.png)
#
# 点进去，选Jupyter，点进去，点install
#
# ![jupyter.png](attachment:image.png)
#
# install成功之后应该长这样：
#
# ![jupyter_installed.png](attachment:jupyter_installed.png)
#
#
# ## 零点二、环境配置
# Python 官网：https://www.python.org/
#
# Python环境配置：https://www.runoob.com/python3/python3-install.html
#
# Python VSCode配置：https://www.runoob.com/python3/python-vscode-setup.html
#
# ## 一、print("Hello,world!")
# 1. 第一个字符必须以字母（a-z, A-Z）或下划线 _ 。
# 2. 标识符的其他的部分由字母、数字和下划线组成。
# 3. 标识符对大小写敏感，count 和 Count 是不同的标识符。
# 4. 标识符对长度无硬性限制，但建议保持简洁（一般不超过 20 个字符）。
# 5. 禁止使用保留关键字，如 if、for、class 等不能作为标识符。
# 6. 单行注释：#
# 7. 多行注释：'''
# 8. 缩进
# 9. 但如果语句很长，用 \ 来实现多行语句
# 10. 记得不要肌肉记忆写分号！

# %% [markdown]
# <style>
#     .CodeMirror, .text_cell_render {
#         font-family: "宋体" !important;
#         font-size: 16px !important;
#     }
# </style>

# %%
print("Hello,world!")
# Out:
# Hello,world!

# %%
'''
This is
a lot of
comments.
'''
print("hahaha")
# lalala
print("yeahhh")
# Out:
# hahaha
# yeahhh

# %%
# 并不需要提前定义，可以突然冒出来一个变量

list = ["apple", "orange", "pear", 1]
for fruit in list:
    print(fruit)
# Out:
# apple
# orange
# pear
# 1

# %% [markdown]
# Python依赖“缩进”判断代码属于哪一部分。
#
# 缩进相当于整理文件袋，比如：教室（第一层）里有很多书包（第二层）里放了很多文件夹（第三层），文件夹里放了很多试卷（第四层）。
# 如果试卷在教室里乱飞，那就乱套了。
#
# Python也会生气：“你的代码乱套了！（IndentationError）”

# %%
for i in range (1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## 二、变量、类型、运算符
# ### 变量与类型
# ```
# counter = 100          # 整型变量
# miles   = 1000.0       # 浮点型变量
# name    = "runoob"     # 字符串
# ```
# python 中单引号 `'` 和双引号 `"` 使用完全相同。
#
# Python允许同时为多个变量赋值：`a = b = c = 1`

# %%
a, b, c = 1, 2, "runoob"
print(a, b, c)

# %%
a = 1 
b = 2 
c = "runoob"
print(a,b,c)

# %% [markdown]
# 可以通过 type() 函数查看变量的类型：
# ```
# print(type(x))         # <class 'int'>
# print(type(y))         # <class 'float'>
# print(type(name))      # <class 'str'>
# print(type(is_active)) # <class 'bool'>
# ```
# ### 转换
# ```
# x = int(1)   # x 输出结果为 1
# y = int(2.8) # y 输出结果为 2
# z = int("3") # z 输出结果为 3
# ```
# ```
# x = float(1)     # x 输出结果为 1.0
# y = float(2.8)   # y 输出结果为 2.8
# z = float("3")   # z 输出结果为 3.0
# w = float("4.2") # w 输出结果为 4.2
# ```
# ```
# x = str("s1") # x 输出结果为 's1'
# y = str(2)    # y 输出结果为 '2'
# z = str(3.0)  # z 输出结果为 '3.0'
# ```
# ### 运算符
# `/`	除 - x 除以 y
#
# `%`	取模 - 返回除法的余数
#
# `**`	幂 - 返回x的y次幂
#
# `//`	向下取整
#
# `:=`	海象运算符（Walrus Operator）， 看起来像一只海象的眼睛和獠牙 🦭
#
# 这个运算符的主要目的是在表达式中同时进行赋值和返回赋值的值。
# 在这个示例中，赋值表达式可以避免调用 len() 两次:

# %%
a = "Hello World"
if (n := len(a)) > 10:
    print(n)
    print(f"List is too long ({n} elements, expected <= 10)")

# %%
a = "Hello World"
n = len(a)
if (n) > 10:
    print(f"List is too long ({n} elements, expected <= 10)")

# %% [markdown]
# #### Python位运算符
# 主要用于底层编程、硬件控制、协议解析、加密算法、优化计算等场景
#
# ![alt text](image.png)
# #### Python逻辑运算符
# ![alt text](image-2.png)
# #### Python成员运算符
# ![alt text](image-1.png)
#
# ## 三、条件判断与循环
# ### if

# %%
age = 18
if age >= 18:
    print("adult")
elif age >= 14:
    print("adolesent")
else:
    print("child")

# %% [markdown]
# ### while

# %%
i = 0
while i < 5:
    print(i)
    i += 1

# %% [markdown]
# ### for

# %%
for i in range(5):
    print(i)

# %%
# 控制步长
for i in range(0, 10, 2):
    print(i)

# %%
# 递减步长
for i in range(10, 0, -2):
    print(i)

# %%
# 遍历列表时控制步长（切片）
my_list = [10, 20, 30, 40, 50, 60, 70]
# 各一个元素取一次
for item in my_list[::2]:
    print(item)

# %%
my_list = [10, 20, 30, 40, 50, 60, 70]
# 各两个元素取一次
for item in my_list[::3]:
    print(item)

# %% [markdown]
# ## 四、数据结构
# ### list
# ```
# fruits = ["apple", "banana", "cherry"]
# print(fruits[0])   # apple
# ```
# 列表中元素的类型可以不相同，它支持数字，字符串甚至可以包含列表（所谓嵌套）。列表是写在方括号 `[]` 之间、用逗号分隔开的元素列表。和字符串一样，列表同样可以被索引和截取，列表被截取后返回一个包含所需元素的新列表。
#
# 列表索引：
#
# ![alt text](1752227442545.png)
#
# ![alt text](1752227501295.png)
#
# 列表截取语法如下：
# ```
# 变量[头下标:尾下标+1]
# ```
#
# ![alt text](1752224854335.png)
#
# list中的内容可以改变。

# %%
# get a sublist
fruits = ["apple", "banana", "grape", "pear", "orange"]
print(fruits[1:4])

# %%
# change value in list
fruits = ["apple", "banana", "grape", "pear", "orange"]
print(fruits[0])
fruits[0] = "watermelon"
print(fruits[0])

# %% [markdown]
# ### disk
#
# 字典是一种可变容器模型，且可存储任意类型对象。
#
# 字典的每个键值 key=>value 对用冒号 `:` 分割，每个对之间用逗号 `(,)` 分割，整个字典包括在花括号 `{}` 中 ,格式如下所示：
# ```
# d = {key1 : value1, key2 : value2, key3 : value3 }
# ```
#
# ![alt text](1752227777500.png)

# %%
person = {"name": "Jack", "age": 21}
print(person["name"])
print(person["age"])

# %% [markdown]
# ### tuple
# ```
# t = (1, 2, 3)
# ```
# 元组（tuple）与列表类似，不同之处在于元组的元素不能修改。元组写在小括号 () 里，元素之间用逗号隔开。
#
# 元组中的元素类型也可以不相同：
# ```
# tuple = ( 'abcd', 786 , 2.23, 'runoob', 70.2  )
# ```
# ![alt text](1752227642756.png)

# %%
# empty tuple
empty_tuple = ()

# 单元素（必须有逗号）
single_item = (42,)
print(type(single_item))
single_item_1 = (42)
print(type(single_item_1))

# 多元素
colors = ("red", "green", "blue")
coordinates = (3.5, 8.2)

# %%
# tuple不能改变
colors = ("red", "green", "blue")
print(colors(0))
colors(0) = "yellow"
print(colors(0))

# %% [markdown]
# ### set
#
# Set是一种无序、可变的数据类型，用于存储唯一的元素。
# 集合中的元素不会重复，并且可以进行交集、并集、差集等常见的集合操作。
#
# 在 Python 中，集合使用大括号 {} 表示，元素之间用逗号 , 分隔。
# 另外，也可以使用 set() 函数创建集合。
#
# 注意：创建一个空集合必须用 set() 而不是 { }，因为 { } 是用来创建一个空字典。

# %%
# 自动去重
fruits = {"banana", "apple", "orange", "apple", "orange"}
print(fruits)

# %% [markdown]
# ## 五、 推导式
#
# 推导式是一种独特的数据处理方式，可以从一个数据序列构建另一个新的数据序列的结构体。
#
# ### 列表推导式 List Comprehension
# ```
# [out_exp_res for out_exp in input_list]
# [out_exp_res for out_exp in input_list if condition]
# ```
# 实例：

# %%
# 过滤掉长度小于或等于3的字符串列表，并将剩下的转换成大写字母
names = ['Bob','Tom','alice','Jerry','Wendy','Smith']
new_names = [name.upper()for name in names if len(name)>3]
print(new_names)

# %%
# 计算 30 以内可以被 3 整除的整数
multiples = [i for i in range(30) if i % 3 == 0]
print(multiples)

# %% [markdown]
# ### 字典推导式 Dictionary Comprehension
# ```
# { key_expr: value_expr for value in collection }
# { key_expr: value_expr for value in collection if condition }
# ```

# %%
# 将列表转为字典（元素作为键，平方作为值）
numbers = [1, 2, 3, 4]
squared_dict = {x: x**2 for x in numbers}
print(squared_dict)

# %%
# 将字符串列表转为字典（字符串作为键，长度作为值）
fruits = ["apple", "banana", "cherry"]
length_dict = {fruit: len(fruit) for fruit in fruits}
print(length_dict)

# %% [markdown]
# ### 元组推导式
# ```
# (expression for item in Sequence )
# (expression for item in Sequence if conditional )
# ```
# 元组推导式和列表推导式的用法完全相同，只是元组推导式是用 `()` 圆括号将各部分括起来，而列表推导式用的是中括号 `[]` 。

# %% [markdown]
# ### 集合推导式
# ```
# { expression for item in Sequence }
# { expression for item in Sequence if conditional }
# ```

# %%
# 只保留偶数
numbers = [1, 2, 3, 3, 4, 5, 5, 6, 6, 6, 6]
even_numbers = {x for x in numbers if x % 2 == 0}
print(even_numbers)

# %%
# 把字符变成对应的长度
words = ["apple", "banana", "cherry", "apple"]
lengths = {len(word) for word in words}
print(lengths)

# %% [markdown]
# ## 六、迭代器与生成器
# ### 迭代器 Iterator (iter & next)
# 迭代器能让你逐个访问集合元素
#
# 它知道"下一个"是什么，但不知道"上一个"或"全部"
#
# 有点像这个东西（单向的链表）：
#
# ```
# typedef struct Node {
#     int data;
#     struct Node *next;
# } Node;
# ```

# %%
my_list = [1, 2, 3]
it = iter(my_list)

print(next(it))  # 1
print(next(it))  # 2
print(next(it))  # 3
# 再next()就报错，因为没元素了

# %%
# 用try避免一直next报错
my_list = [1, 2, 3]
it = iter(my_list)

while True:
    try:
        print(next(it))
    except StopIteration:
        print("end")
        break

# %% [markdown]
# 好处：
#
# 1. 节省内存（不需要一次性加载所有数据）
#
# 2. 统一访问各种数据结构的接口（列表、字典、文件等都可用同样方式遍历）
# ### 生成器 Generator
# #### 生成器函数（yield）
#
# 生成器本质上是一个 迭代器（Iterator），通过yield函数暂停迭代，并保存当前状态。
#
# 函数输出之后不会终止，而是暂停并保留所有局部状态，下次调用时从上次暂停的位置继续执行。（对比return）

# %%
def count_to_infinity():
    n = 0
    while True:
        yield n
        n += 1

lazy_counter = count_to_infinity()  # 不会卡死你的电脑
print(next(lazy_counter))  # 0
print(next(lazy_counter))  # 1
# 可以一直next下去...

# %%
# fibonacci, 避免绕脑子的recursion
def fibonacci(limit):
    a, b = 0, 1
    while a < limit:
        yield a
        a, b = b, a + b

for num in fibonacci(100):
    print(num)

# %%
# 委托生成 yield from
def sub_generator():
    yield "Python"
    yield "Rust"

def main_generator():
    yield "Hello"
    yield from sub_generator()
    yield "World"

for word in main_generator():
    print(word)

# %% [markdown]
# #### 生成器表达式

# %%
# 普通list
squares = [x*x for x in range(1000000)] # generate all at once，memory explode

# %%
# 生成器表达式，只有在调用 next() 或迭代时，才会计算当前值
lazy_squares = (x*x for x in range(1000000))
print(next(lazy_squares))
print(next(lazy_squares))

# %% [markdown]
# ## 七、函数与模块
# ### function definition

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Jack"))

#f 表示这是一个 格式化字符串（formatted string），允许在字符串中直接嵌入变量或表达式。
#{name} 是一个 占位符，它会被变量 name 的值替换。

# %% [markdown]
# ### 导入模块
# Python 有很多好用的库

# %%
import math
print(math.sqrt(16))

# %% [markdown]
# 将整个模块(somemodule)导入，格式为：
# ```
# import somemodule`
# ```
#
# 从某个模块中导入某个函数,格式为：
# ```
# from somemodule import somefunction
# ```
#
# 从某个模块中导入多个函数,格式为：
# ```
# from somemodule import firstfunc, secondfunc, thirdfunc
# ```
#
# 将某个模块中的全部函数导入，格式为：
# ```
# from somemodule import *
# ```
# ## 八、文件、异常、类
# ### 文件读写
# ```
# with open("hello.txt", "w") as f:
#     f.write("Hello world!")
# ```
# ### 异常处理
# ```
# try:
#     x = 1 / 0
# except ZeroDivisionError:
#     print("除0错误！")
#
# ```
# ### 类和对象
#
# “类”就像“狗的品种”
#
# 比如“泰迪犬”是一个品种（类），它定义了这类狗的共同特点（名字、会叫）。
#
# 你家的“小白”是具体的某一只泰迪（对象），它是根据“泰迪犬”这个品种创造出来的。
#
# 想象你买了一只新狗狗，回家第一件事是给它起名字、戴项圈、放水碗。
#
# `__init__` 就是“初始化”这只狗的过程——新狗到家时必须做的准备工作。
#
# `__init__` 是构造函数，创建对象时自动调用。
#
# self 代表这只狗自己（比如“小白的碗”就是 self.bowl）。

# %%
class TeddyDog:
    def __init__(self, name):
        self.name = name
        self.bowl = "empty" # No dog food!   

    def bark(self):
        print(f"{self.name}: Wolf!")

    def sit(self):
        print(f"{self.name}: sit!")

dog1 = TeddyDog("Little_White")
dog2 = TeddyDog("Little_Black")
dog1.bark()
dog2.bark()
dog1.sit()
dog2.sit()
# Out:
# Little_White: Wolf!
# Little_Black: Wolf!
# Little_White: sit!
# Little_Black: sit!

# %% [markdown]
# ### Private and Public
#
# Public：像狗狗的“名字”，谁都可以问：“你叫啥？”
#
# (属性/方法名无下划线（如 name），外部可直接访问。)
#
# Private：像狗狗的“肠胃健康”，只有兽医（类内部）能检查，外人不能随便碰！
#
# (属性/方法名加双下划线（如 __stomach），仅限内部使用，外部访问会报错)

# %%
class TeddyDog:
    def __init__(self, name):
        self.name = name
        self.__stomach = "healthy"

    def check_health(self):
        print(f"{self.name}'s stomach: {self.__stomach}")

dog = TeddyDog("Little_White")
print(dog.name)
# print(dog.__stomach) # wrong!
dog.check_health()

# %% [markdown]
# ---
# 更多细节请咨询 https://www.runoob.com/python3/python3-tutorial.html

# %% [markdown]
# by: 2025 SSTIA
#
# 马匀菲
